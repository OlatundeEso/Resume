# %% [markdown]
# <a href="https://colab.research.google.com/github/OlatundeEso/Resume/blob/main/My_Simple_Text_Generator_Model_23122022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, MultiHeadAttention, Dense, LayerNormalization
from tensorflow.keras.utils import to_categorical

# Corpus for training
corpus = [
    "This is a sample sentence.",
    "Another example for self-supervised learning.",
    "Medical science is a great course of study.",
    "NLP tasks can benefit from self-supervised methods."
]

# Tokenize the corpus into words
tokenized_corpus = [tf.keras.preprocessing.text.text_to_word_sequence(sentence) for sentence in corpus]

# Derive input and target sequences
input_sequences = []
target_sequences = []

for sentence_tokens in tokenized_corpus:
    for i in range(len(sentence_tokens) - 1):
        input_sequences.append(sentence_tokens[:i + 1])
        target_sequences.append(sentence_tokens[i + 1])

# Flatten the list of input sequences
flat_input_sequences = [' '.join(seq) for seq in input_sequences]

# Tokenize the input sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(flat_input_sequences)
total_words = len(tokenizer.word_index) + 1

# Convert input and target sequences to numerical sequences
input_sequences_numeric = tokenizer.texts_to_sequences(flat_input_sequences)
target_sequences_numeric = tokenizer.texts_to_sequences(target_sequences)

# Pad sequences for a consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences_numeric])
padded_input_sequences = pad_sequences(input_sequences_numeric, maxlen=max_sequence_length, padding='pre')
padded_target_sequences = pad_sequences(target_sequences_numeric, maxlen=max_sequence_length, padding='pre')
padded_target_sequences_one_hot = to_categorical(padded_target_sequences, num_classes=total_words)

# Build the Transformer model using MultiHeadAttention layer
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential(
            [tf.keras.layers.Dense(ff_dim, activation="relu"), tf.keras.layers.Dense(embed_dim),]
        )
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length))
model.add(TransformerBlock(embed_dim=50, num_heads=4, ff_dim=100))
model.add(Dense(total_words, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(padded_input_sequences, padded_target_sequences, epochs=100, verbose=2)

def generate_text(model, tokenizer, max_sequence_length, seed_text, next_words=1):
    generated_text = seed_text
    for _ in range(next_words):
        # Tokenize the input text
        seed_text_tokens = tf.keras.preprocessing.text.text_to_word_sequence(seed_text)
        # Convert input sequence to numerical sequence
        seed_sequence_numeric = tokenizer.texts_to_sequences([' '.join(seed_text_tokens)])[0]
        # Pad the input sequence
        padded_seed_sequence = pad_sequences([seed_sequence_numeric], maxlen=max_sequence_length, padding='pre')
        # Use the model to predict the next token probabilities
        predicted_probs = model.predict(padded_seed_sequence, verbose=0)[0]
        # Select the index with the highest probability
        predicted_index = np.random.choice(len(predicted_probs))
        # Decode the predicted token to obtain the word
        predicted_word = tokenizer.index_word.get(predicted_index, '')
        # Update the seed text for the next iteration
        seed_text += ' ' + predicted_word
        generated_text += ' ' + predicted_word

    return generated_text

# Example usage with temperature adjustment
seed_text = "Great"
generated_text = generate_text(model, tokenizer, max_sequence_length, seed_text, next_words=10)
print("Generated Text:", generated_text)
# Out:
# Epoch 1/100
# 1/1 - 3s - loss: 4.6542 - accuracy: 0.0186 - 3s/epoch - 3s/step
# Epoch 2/100
# 1/1 - 0s - loss: 3.0062 - accuracy: 0.1242 - 26ms/epoch - 26ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 1.7746 - accuracy: 0.6832 - 23ms/epoch - 23ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 1.0816 - accuracy: 0.8696 - 23ms/epoch - 23ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 0.8767 - accuracy: 0.8820 - 26ms/epoch - 26ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 0.7737 - accuracy: 0.8820 - 21ms/epoch - 21ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 0.7659 - accuracy: 0.8820 - 24ms/epoch - 24ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 0.7628 - accuracy: 0.8820 - 31ms/epoch - 31ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 0.7330 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 0.7576 - accuracy: 0.8820 - 25ms/epoch - 25ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 0.7469 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 0.7183 - accuracy: 0.8820 - 28ms/epoch - 28ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 0.7365 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 0.7092 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 0.6954 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 0.6647 - accuracy: 0.8820 - 19ms/epoch - 19ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 0.6602 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 0.6262 - accuracy: 0.8820 - 18ms/epoch - 18ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 0.6163 - accuracy: 0.8820 - 22ms/epoch - 22ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 0.5775 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 0.6067 - accuracy: 0.8820 - 24ms/epoch - 24ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 0.5750 - accuracy: 0.8820 - 24ms/epoch - 24ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 0.5633 - accuracy: 0.8820 - 21ms/epoch - 21ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 0.5577 - accuracy: 0.8820 - 23ms/epoch - 23ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 0.5458 - accuracy: 0.8820 - 29ms/epoch - 29ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 0.5567 - accuracy: 0.8820 - 22ms/epoch - 22ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 0.5635 - accuracy: 0.8820 - 24ms/epoch - 24ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 0.5464 - accuracy: 0.8820 - 26ms/epoch - 26ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 0.5125 - accuracy: 0.8820 - 28ms/epoch - 28ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 0.5081 - accuracy: 0.8820 - 28ms/epoch - 28ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 0.4946 - accuracy: 0.8758 - 20ms/epoch - 20ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 0.5068 - accuracy: 0.8820 - 25ms/epoch - 25ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 0.4882 - accuracy: 0.8820 - 22ms/epoch - 22ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 0.4661 - accuracy: 0.8820 - 21ms/epoch - 21ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 0.4685 - accuracy: 0.8820 - 19ms/epoch - 19ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 0.4492 - accuracy: 0.8820 - 19ms/epoch - 19ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 0.4460 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 0.4452 - accuracy: 0.8758 - 19ms/epoch - 19ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 0.4313 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 0.3983 - accuracy: 0.8882 - 19ms/epoch - 19ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 0.4216 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 0.4076 - accuracy: 0.8882 - 20ms/epoch - 20ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 0.3911 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 0.3873 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 0.3745 - accuracy: 0.8882 - 21ms/epoch - 21ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 0.3843 - accuracy: 0.8634 - 21ms/epoch - 21ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 0.3843 - accuracy: 0.8758 - 20ms/epoch - 20ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 0.3713 - accuracy: 0.8696 - 22ms/epoch - 22ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 0.3614 - accuracy: 0.8820 - 22ms/epoch - 22ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 0.3497 - accuracy: 0.8758 - 20ms/epoch - 20ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.8820 - 25ms/epoch - 25ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.3326 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.3142 - accuracy: 0.8758 - 27ms/epoch - 27ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.3327 - accuracy: 0.8944 - 23ms/epoch - 23ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.3306 - accuracy: 0.8758 - 21ms/epoch - 21ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.3024 - accuracy: 0.8882 - 21ms/epoch - 21ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.3339 - accuracy: 0.8882 - 20ms/epoch - 20ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.3027 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.2820 - accuracy: 0.8944 - 19ms/epoch - 19ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.2787 - accuracy: 0.9006 - 20ms/epoch - 20ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.2917 - accuracy: 0.8944 - 19ms/epoch - 19ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.2642 - accuracy: 0.8820 - 20ms/epoch - 20ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.2444 - accuracy: 0.9006 - 20ms/epoch - 20ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.2483 - accuracy: 0.8820 - 26ms/epoch - 26ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.2408 - accuracy: 0.8944 - 20ms/epoch - 20ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.2269 - accuracy: 0.9068 - 28ms/epoch - 28ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.2326 - accuracy: 0.9068 - 24ms/epoch - 24ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.1998 - accuracy: 0.9255 - 25ms/epoch - 25ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.2177 - accuracy: 0.9068 - 25ms/epoch - 25ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.2031 - accuracy: 0.9130 - 19ms/epoch - 19ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.2001 - accuracy: 0.9317 - 20ms/epoch - 20ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.1950 - accuracy: 0.9255 - 26ms/epoch - 26ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.1801 - accuracy: 0.9379 - 19ms/epoch - 19ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.1674 - accuracy: 0.9503 - 20ms/epoch - 20ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.1719 - accuracy: 0.9441 - 19ms/epoch - 19ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.1657 - accuracy: 0.9627 - 25ms/epoch - 25ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.1675 - accuracy: 0.9503 - 19ms/epoch - 19ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.1556 - accuracy: 0.9627 - 20ms/epoch - 20ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.1538 - accuracy: 0.9689 - 21ms/epoch - 21ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.1383 - accuracy: 0.9752 - 19ms/epoch - 19ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.1391 - accuracy: 0.9627 - 19ms/epoch - 19ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.1383 - accuracy: 0.9752 - 19ms/epoch - 19ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.1444 - accuracy: 0.9565 - 20ms/epoch - 20ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.1249 - accuracy: 0.9814 - 21ms/epoch - 21ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.1267 - accuracy: 0.9752 - 22ms/epoch - 22ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.1236 - accuracy: 0.9814 - 24ms/epoch - 24ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.1063 - accuracy: 0.9938 - 25ms/epoch - 25ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.1103 - accuracy: 0.9876 - 24ms/epoch - 24ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.1146 - accuracy: 0.9876 - 27ms/epoch - 27ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.1066 - accuracy: 0.9876 - 25ms/epoch - 25ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.1102 - accuracy: 0.9689 - 20ms/epoch - 20ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.0900 - accuracy: 0.9876 - 25ms/epoch - 25ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.0934 - accuracy: 0.9876 - 32ms/epoch - 32ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.0944 - accuracy: 0.9814 - 20ms/epoch - 20ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.0870 - accuracy: 0.9814 - 21ms/epoch - 21ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.0816 - accuracy: 0.9938 - 24ms/epoch - 24ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.0832 - accuracy: 0.9938 - 19ms/epoch - 19ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.0897 - accuracy: 0.9876 - 21ms/epoch - 21ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.0725 - accuracy: 0.9938 - 19ms/epoch - 19ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.0710 - accuracy: 0.9938 - 19ms/epoch - 19ms/step
# Generated Text: Great nlp medical  nlp nlp tasks medical nlp medical is
